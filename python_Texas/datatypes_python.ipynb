# %% [markdown]
# # data types in python
# 1. python have 3 data types
# 2. int ( integer)
# 3. str(string)
# 4. float(decimals)

# %%
name ="abbhinav"
age = 22
height = 5.9
print(name)
print(age)
print(height)

# %%
data=("120")
print(data)
