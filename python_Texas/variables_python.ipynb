# %% [markdown]
# # Variables in python
# 1. variables is memory allocation to value
# 2. examples are name="abbhinav", age=26 , salary=100000.50
#
# # Key points to define variables
# 1. variable do not satrt with digit
# 2. variable does not allowed special charecters
# 3. do not use keywords as a variable

# %%
name="abbhinav"
age="18"
salary="100000.40"
print(name)
print(age)
print(salary)
# Out:
# abbhinav
# 18
# 100000.40
