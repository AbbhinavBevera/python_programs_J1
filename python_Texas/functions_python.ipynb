# %% [markdown]
# # function in python
# 1. function is aset of instructions that performs a specific task
# 2. function are two types
#    a. built-in function
#    b. user-defined function
# 3. pre-defined function 'dir()' is used to display all the functions available in a particular data structure like list,dict,set etc.
#
# ''' python
# def function_name(args):
#     statement1...
#     statement(s)
# function_name(args)
# '''

# %%
print ("print statement returns output")
print("sum[1,2,3]=")
print(type("shiva"))
print(pow(2,5))
print(sorted)
# Out:
# print statement returns output
# sum[1,2,3]=
# <class 'str'>
# 32
# <built-in function sorted>

# %%
#write a pragram to sum of two numbers using function
def add_numbers():
    input1=int(input("enter first number:"))
    input2=int(input("enter second number:"))
    result=input1+input2
    return result
print("sum of two numbers=",add_numbers())
# Out:
# sum of two numbers= 30

# %%
#write a program to print addition of two strings
def add_strings():
    a = input("Enter first string: ")
    b = input("Enter second string: ")
    result = a + b
    return result
print("addition of two strings=", add_strings())

# %%
#write a program to print profile data function with arguments
def profile_data(name, age, city):
    print("Name:", name)
    print("Age:", age)  
    print("City:", city)
    return
print(profile_data("Shiva", 25, "New York"))
print(profile_data("Anita", 30, "Los Angeles"))
# Out:
# Name: Shiva
# Age: 25
# City: New York
# None
# Name: Anita
# Age: 30
# City: Los Angeles
# None
